# %% [markdown]
# # University of Stirling
#
# ## ITNPBD2 Representing and Manipulating Data
#
# ## Assignment Autumn 2025
#
# ## A Consultancy Job for JC Penney

# %%
# Importing libraries needed

import os
import json
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Making sure I am in the correct directory to import files

os.getcwd()
# Out:
# 'C:\\Users\\Danie'

# %%
# Changing to directory where files are stored

os.chdir("C:\\Users\\Danie")

# %% [markdown]
# # Initial data exploration and cleaning
#
# I started by loading the csv and json files into panda data frames and used general data description functions to begin understanding the datasets.

# %% [markdown]
# ## Products.csv initial exploration
#
# Here I imported the data set into a pandas dataframe and began to look at the shape and contents of the data

# %%
products_csv = pd.read_csv("products.csv") # Importing data

display(products_csv.head()) 

print(products_csv.shape) # Checking size of data set
print(products_csv.count()) # Using the count function has showed that the SKU, Description, and Price columns are missing some data
print(products_csv.isnull().sum()) # Further to the .count() funtion, I am finding out how many values are missing from each column
print(products_csv.dtypes) # Checking data types
# Out:
# (7982, 6)
# Uniq_id        7982
# SKU            7915
# Name           7982
# Description    7439
# Price          5816
# Av_Score       7982
# dtype: int64
# Uniq_id           0
# SKU              67
# Name              0
# Description     543
# Price          2166
# Av_Score          0
# dtype: int64
# Uniq_id         object
# SKU             object
# Name            object
# Description     object
# Price          float64
# Av_Score       float64
# dtype: object

# %% [markdown]
# ## Users.csv initial exploration
#
# Here I imported the data set into a pandas dataframe and began to look at the shape and contents of the data

# %%
users = pd.read_csv("users.csv")

display(users.head())

print(users.shape) # Checking size of data set
print(users.isnull().sum()) #Checking for missing values
print(users.dtypes) #Checking data types
# Out:
# (5000, 3)
# Username    0
# DOB         0
# State       0
# dtype: int64
# Username    object
# DOB         object
# State       object
# dtype: object

# %% [markdown]
# ## Reviews.csv initial exploration
#
# Here I imported the data set into a pandas dataframe and began to look at the shape and contents of the data

# %%
# Same process as above, importing data set, looking at size of dataframe, checking for missing values

reviews_csv = pd.read_csv("reviews.csv")

display(reviews_csv.head())

print(reviews_csv.shape)
print(reviews_csv.isnull().sum())
print(reviews_csv.dtypes)
# Out:
# (39063, 4)
# Uniq_id     0
# Username    0
# Score       0
# Review      0
# dtype: int64
# Uniq_id     object
# Username    object
# Score        int64
# Review      object
# dtype: object

# %% [markdown]
# ## jcpenney_products.json initial exploration and cleaning
#
# Imported data in pandas, explored data and perfomed basic cleaning

# %%
# Same process as above, importing data set, looking at size of dataframe, checking for missing values

products_json = pd.read_json("jcpenney_products.json", lines = True)

display(products_json.head(10))

print(products_json.shape)
print(products_json.count())
print(products_json.isnull().sum())
print(products_json.dtypes)
# Out:
#                             uniq_id           sku  \
# 0  b6c0b6bea69c722939585baeac73c13d  pp5006380337
# 1  93e5272c51d8cce02597e3ce67b7ad0a  pp5006380337
# 2  013e320f2f2ec0cf5b3ff5418d688528  pp5006380337
# 3  505e6633d81f2cb7400c0cfa0394c427  pp5006380337
# 4  d969a8542122e1331e304b09f81a83f6  pp5006380337
# 5  cf73bb2bd93bbd6e1bdf48d399992270  pp5006380337
# 6  8ffd0ef4fcaf1a82fb514aba5d20e05b  pp5006790247
# 7  4d9337e3c8f974d3c420cdc5c58b3fc3  pp5007090172
# 8  44f8f8f108c6856acf9630dd1d78516d  pp5007080134
# 9  8d1d057f5f808c10ce243c222ab0ef6e  pp5007080134
#
#                                           name_title  \
# 0        Alfred Dunner® Essential Pull On Capri Pant
# 1        Alfred Dunner® Essential Pull On Capri Pant
# 2        Alfred Dunner® Essential Pull On Capri Pant
# 3        Alfred Dunner® Essential Pull On Capri Pant
# 4        Alfred Dunner® Essential Pull On Capri Pant
# 5        Alfred Dunner® Essential Pull On Capri Pant
# ...

# %%
products_json.replace("", np.nan, inplace=True) #replacing empty strings with Nan
print(products_json.isnull().sum()) #Looking for missing values

print(products_json.dtypes)

# %% [markdown]
# ## jcpenney_reviewers.json initial exploration and cleaning

# %%
#As above, loading datafreame, looking at size and for missing values

reviews_json = pd.read_json("jcpenney_reviewers.json", lines=True)

display(reviews_json.head())

print(reviews_json.shape)
print(reviews_json.count())
print(reviews_json.isnull().sum())
# Out:
# (5000, 4)
# Username    5000
# DOB         5000
# State       5000
# Reviewed    5000
# dtype: int64
# Username    0
# DOB         0
# State       0
# Reviewed    0
# dtype: int64

# %%
reviews_json.replace("", np.nan, inplace=True) #replacing empty strings with Nan
print(reviews_json.isnull().sum()) #Checking for missing values
# Out:
# Username    0
# DOB         0
# State       0
# Reviewed    0
# dtype: int64

# %% [markdown]
# ## Creating a subset to visualise best and worst reviewed products

# %% [markdown]
# Doing some further cleaning on this dataset before creating a subset for the purpose of visualising best and worst reviewed products

# %%
#Changing datatype to float

products_json["list_price"] = products_json["list_price"].astype(float)

# %%
#When I initially ran the function to convert object to float, there was an error because some prices were in ranges.
#Changing values to numeric data and ranges to Nan values

products_json["sale_price"] = pd.to_numeric(products_json["sale_price"], errors = "coerce")

# %%
#Changing datatype to float

products_json["sale_price"] = products_json["sale_price"].astype(float)

# %% [markdown]
# # In the first half of my analysis, I focused on drawing insghts and creating visualisations based on products
#
# I decided to look at average product ratings and from this, identify the best and worst reviewed products and brands

# %% [markdown]
# ## Creating subset of Products JSON to show true average value by SKU
#
# As each entry has an individual "averge rating", I created a subset and took an overall average for each product grouped by SKU to represent an individual product.

# %%
products_json["sku"] = products_json["sku"].astype(str) 
#I was getting an error when running the code in cell 81, converting to a str fixed this

# %%
products_json.head()

# %%
#Creating a more manageable subset to group the SKU's and get an overall mean for each

subset = products_json[["name_title","sku","average_product_rating","total_number_reviews"]]

#Removing empty values in sku column

subset = subset[subset["sku"] != "nan"]

# %%
#display(subset.head())
print(subset.dtypes)
# Out:
# name_title                 object
# sku                        object
# average_product_rating    float64
# total_number_reviews        int64
# dtype: object

# %%
# There are muptiple rows for each sku so I am grouping them together and caluclating the average of the
#"average_product_ rating" to get an average rating for each product

subset = subset.groupby(["name_title","sku"]).agg(
    total_av = ("average_product_rating","mean"), 
    total_reviews = ("total_number_reviews","sum"))

# %%
#Sorting to see which products have the most/least reviews

subset_sorted = subset.sort_values(by = "total_reviews", ascending = False) #sorting values by descending order, total reviews to top

display(subset_sorted)
# Out:
#                                                                  total_av  \
# name_title                                         sku
# Stafford® Gunner Mens Cap Toe Leather Boots        pp5004560042  2.777778
# Clarks® Leisa Grove Leather Sandals                pp5006210554  3.125000
# Xersion™ Quick-Dri Performance Bootcut Pant        pp5005870510  3.057692
# Clarks® Leisa Grove Leather Sandals - Wide Width   pp5006210555  3.050595
# Xersion™ Quick-Dri Performance Capris              pp5004201437  3.012500
# ...                                                                   ...
# 1928® Light Blue Stone Silver-Tone Flower Necklace pp5006260213  5.000000
# 100 Facets by DiamonArt® Square Cubic Zirconia ... pp5003190982  4.000000
# St. John's Bay® Geometric Print Tankini Swim To... pp5006460092  1.000000
# St. John's Bay® High-Waist Skirted Swim Bottoms... pp5006460086  1.000000
# St. John's Bay® High-Waist Swim Bottoms - Plus     pp5006460087  5.000000
#
# ...

# %%
print(sum(subset_sorted["total_reviews"] > 10))
# I recognised above that if I were to plot the subset that the data would be skewed by the products which only have 1 review.
# Therefore, I decided to only plot products which have more than 10 reviews
# Here I am checking how many products meet that condition
# Out:
# 764

# %%
# Creating a new sub set with products which have more than 10 reviews

x = subset_sorted["total_reviews"] > 10

top_reviewed = subset_sorted[x].reset_index() 

# Sorting by highest average review

top_reviewed_ordered = top_reviewed.sort_values(by = "total_av", ascending = False)

# Creating smaller subsets of the top and bottom 10 products by average review so that they fit on a bar chart

top_10 = top_reviewed_ordered.head(10) #Creating subsets top and bottom products by average rating 

bottom_10 = top_reviewed_ordered.tail(10)

bottom_10.loc[436, "name_title"] = "Zeroxposur® Static Wide-Strap Tankini Swim Wear" #Renaming long product name which was difficult to read on graph

# %%
display(bottom_10)
# Out:
#                                             name_title           sku  \
# 193   Okie Dokie® Print Leggings - Toddler Girls 2t-5t  pp5005760351
# 734                    Keurig® K250 2.0 Compact Brewer  pp5005140282
# 643  Total Girl® Printed Capri Leggings - Girls 7-1...  pp5006081442
# 695                     Arizona Long-Sleeve Polo Shirt  pp5002760285
# 610                   Foreo Luna™ For Combination Skin  pp5005960565
# 246                               Wicker Chair Cushion  pp5005430549
# 436    Zeroxposur® Static Wide-Strap Tankini Swim Wear  pp5006640562
# 750   Marc Jacobs Beauty Enamored Hi-Shine Nail Polish  pp5006620365
# 356                St. John's Bay® Zaber Thong Sandals  pp5006320143
# 543        St. John's Bay® Short-Sleeve V-Neck T-Shirt  pp5006310918
#
#      total_av  total_reviews
# 193  2.184524             23
# 734  2.181818             11
# 643  2.175000             13
# 695  2.166667             12
# 610  2.142857             14
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Creating a visualisation to look at the top and bottom 10 products by average user rating
# ## Figure 1.1 in report

# %%
plt.figure(figsize=(12,6)) #Setting figure size

plt.subplot(121) #Defining sublot size and position
plt.title("Best 10 Products")
plt.ylabel("Average Customer Rating (Out of 5)")
plt.bar(top_10["name_title"],top_10["total_av"], 
        color="blue",
       edgecolor="black",
       linewidth=0.7) #color, edgecolor, linewidth to improve readbility

plt.xticks(ticks=range(len(top_10)),
           labels=top_10["name_title"],
           rotation=45,
          ha="right",fontsize=12) #rotated x labels to improve readbility

plt.ylim(0,4.2) #Ensuring scale of Y axis is same for both graphs

plt.subplot(122)
plt.title("Worst 10 Products")
plt.bar(bottom_10["name_title"],bottom_10["total_av"],
       color="orangered",
       edgecolor="black",
       linewidth=0.7)

plt.xticks(ticks=range(len(top_10)),
           labels=bottom_10["name_title"],
           rotation=45,
          ha="right",fontsize=12)

plt.ylim(0,4.2)

plt.suptitle("Best and Worst 10 Products by Average Customer Rating", fontsize=16,fontweight="bold")

plt.savefig("best_products_1.png", dpi=300, bbox_inches='tight') #Saving figure to export to report

plt.show()

# %% [markdown]
# This graph would hve been much better displayed as a Plotly graph where the names were shown when hovering over a bar, however, I decided not to use this as the report is a PDF and will not allow for interactive graphs. I also considered a horizontal bar chart but thought the names were too long to fit.

# %% [markdown]
# ## Creating a visualisation to look at the overall average product score (for products with more than 10 reviews)
#
# ## Figure 1 in report

# %%
print(top_reviewed.shape) #To see how many products there are in total
# Out:
# (798, 3)

# %%
product_average = top_reviewed["total_av"].mean() #Calculating a mean average score

# %%
plt.figure(figsize=(8,6))

plt.hist(top_reviewed["total_av"], bins=11,
        color="teal")

plt.axvline(x=product_average,
            color="red",
            linestyle="--",
            linewidth=2,
            label=f"Average Product \n Rating: {product_average: .2f}")

plt.title("Average Customer Product Rating \n (Products with more than 10 reviews)", fontsize=14)
plt.legend()
plt.xlabel("Rating (Out of 5)", fontsize=12,fontweight="bold")
plt.ylabel("Number of Products",fontsize=12,fontweight="bold")

plt.savefig("av_rating.png", dpi=300, bbox_inches='tight') #Saving figure to export to report

plt.show()

# %% [markdown]
# ## Exploring which brands are best and worst reviewed
#
# Here I load the data into pandas, clean by removing unneccessary rows and creating a smaller data subset with average rating and total number of ratings

# %%
df = pd.read_json("jcpenney_products.json", lines=True) #importing data
display(df.head())
# Out:
#                             uniq_id           sku  \
# 0  b6c0b6bea69c722939585baeac73c13d  pp5006380337
# 1  93e5272c51d8cce02597e3ce67b7ad0a  pp5006380337
# 2  013e320f2f2ec0cf5b3ff5418d688528  pp5006380337
# 3  505e6633d81f2cb7400c0cfa0394c427  pp5006380337
# 4  d969a8542122e1331e304b09f81a83f6  pp5006380337
#
#                                     name_title  \
# 0  Alfred Dunner® Essential Pull On Capri Pant
# 1  Alfred Dunner® Essential Pull On Capri Pant
# 2  Alfred Dunner® Essential Pull On Capri Pant
# 3  Alfred Dunner® Essential Pull On Capri Pant
# 4  Alfred Dunner® Essential Pull On Capri Pant
#
#                                          description list_price sale_price  \
# 0  You'll return to our Alfred Dunner pull-on cap...      41.09      24.16
# 1  You'll return to our Alfred Dunner pull-on cap...      41.09      24.16
# 2  You'll return to our Alfred Dunner pull-on cap...      41.09      24.16
# ...

# %%
df.drop(columns = ["product_image_urls", "product_url","Reviews","Bought With","category_tree","category","description"], inplace=True)
display(df.head())

# Making number of columns more manageable by using .drop function to remove columns
# Out:
#                             uniq_id           sku  \
# 0  b6c0b6bea69c722939585baeac73c13d  pp5006380337
# 1  93e5272c51d8cce02597e3ce67b7ad0a  pp5006380337
# 2  013e320f2f2ec0cf5b3ff5418d688528  pp5006380337
# 3  505e6633d81f2cb7400c0cfa0394c427  pp5006380337
# 4  d969a8542122e1331e304b09f81a83f6  pp5006380337
#
#                                     name_title list_price sale_price  \
# 0  Alfred Dunner® Essential Pull On Capri Pant      41.09      24.16
# 1  Alfred Dunner® Essential Pull On Capri Pant      41.09      24.16
# 2  Alfred Dunner® Essential Pull On Capri Pant      41.09      24.16
# 3  Alfred Dunner® Essential Pull On Capri Pant      41.09      24.16
# 4  Alfred Dunner® Essential Pull On Capri Pant      41.09      24.16
#
#    average_product_rating          brand  total_number_reviews
# 0                   2.625  Alfred Dunner                     8
# 1                   3.000  Alfred Dunner                     8
# ...

# %%
# Reducing size further to make a subset for the brand exploration

brands = df[["brand","average_product_rating","total_number_reviews"]]
display(brands.head())
# Out:
#            brand  average_product_rating  total_number_reviews
# 0  Alfred Dunner                   2.625                     8
# 1  Alfred Dunner                   3.000                     8
# 2  Alfred Dunner                   2.625                     8
# 3  Alfred Dunner                   3.500                     8
# 4  Alfred Dunner                   3.125                     8

# %%
unique = brands["brand"].unique() #Finding out how many uninque brand names are in the dataset
display(brands)
print(len(unique))
# Out:
# 721

# %%
# I want to find out what brands have the lowest ratings to see if there are trends but as above, I want to filter out\n
# brands which have less than 10 reviews so we have a reasonable sample size of reviews 
import pandas as pd

brands_sub = brands.groupby("brand").agg(
    average_rating = ("average_product_rating","mean"), 
    total_reviews = ("total_number_reviews","sum")) #Each brand has multiple rows so grouping them together and creating a mean averge rating column

display(brands_sub.head())
print(len(brands_sub)) #Checking how many rows there are (how many brands)
# Out:
#                  average_rating  total_reviews
# brand
# 1928 Jewelry           4.750000              3
# A.N.A                  3.032509           1106
# A2 BY AEROSOLES        3.288046            118
# ACE BAYOU              2.500000             11
# ADIDAS                 3.075809            351
# 721

# %%
brands_sorted = brands_sub.sort_values(by = "average_rating", ascending = False).round(2) #Rounding to 2 decimals for cleaner look
display(brands_sorted.head())
# Out:
#                       average_rating  total_reviews
# brand
# BIALETTI                         5.0              1
# SKYWAY                           5.0              2
# Q-T INTIMATES                    5.0              1
# Bee Darlin Bee Smart             5.0              1
# FIFTH AND PARK                   5.0              1

# %%
x = brands_sorted["total_reviews"] > 10 #Filtering to only include brands with more than 10 reviews so there is a reasonable sample size

# %%
brands_sorted = brands_sorted[x] #Updating data frame to reflect change above

display(brands_sorted.head())
# Out:
#                          average_rating  total_reviews
# brand
# CREATIVE BATH                      4.20             12
# Nicole By Nicole Miller            4.18             21
# SKYLINE FURNITURE                  4.12             14
# UMBRA                              3.98             12
# Nordicware                         3.92             20

# %%
best_brands = brands_sorted.head(10).reset_index()
worst_brands = brands_sorted.tail(10).reset_index().sort_values(by = "total_reviews", ascending = False)

# %%
display(worst_brands)
display(best_brands)
# Out:
#                      brand  average_rating  total_reviews
# 7                Seventeen            2.07             50
# 9                 Warner's            2.05             33
# 2  Certified International            2.33             22
# 0                    FOREO            2.38             22
# 1               John Deere            2.38             14
# 3                   FROZEN            2.29             11
# 5                    Ariya            2.19             11
# 4                  PHILIPS            2.22             11
# 6       MARC JACOBS BEAUTY            2.09             11
# 8         SLEEP PHILOSOPHY            2.06             11
#                      brand  average_rating  total_reviews
# 0            CREATIVE BATH            4.20             12
# 1  Nicole By Nicole Miller            4.18             21
# 2        SKYLINE FURNITURE            4.12             14
# 3                    UMBRA            3.98             12
# ...

# %% [markdown]
# ## Plotting the 10 best and worst reviewed brands
# ## Figure 1.2 in report

# %%
plt.figure(figsize=(7,11)) #Setting figure size

plt.subplot(211) #Defining sublot size and position
plt.title("Best 10 Brands",fontweight="bold")
plt.xlabel("Average Customer Rating (Out of 5)")
plt.barh(best_brands["brand"],best_brands["average_rating"], 
        color="limegreen",
       edgecolor="black",
       linewidth=0.7) #color, edgecolor, linewidth to improve readbility

plt.xlim(0,5) #Ensuring x axis limits are the same for both graphs

plt.subplot(212)
plt.title("Worst 10 Brands",fontweight="bold")
plt.barh(worst_brands["brand"],worst_brands["average_rating"],
       color="orangered",
       edgecolor="black",
       linewidth=0.7)

plt.xlim(0,5)

plt.suptitle("Best and Worst 10 Brands by Average Customer Rating", fontsize=14)

plt.savefig("brands.png", dpi=300, bbox_inches='tight') #Saving figure to export to report

plt.show()

# %% [markdown]
# # Exploring customer data
#
# I am now moving on to analysing and drawing insights from customer data, looking at demographic information - User numbers by US state and reviews by age group

# %%
users_csv = pd.read_csv("users.csv") #importing users data to begin exploration
display(users_csv.head())
print(len(users_csv))
# Out:
#    Username         DOB          State
# 0  bkpn1412  31.07.1983         Oregon
# 1  gqjs4414  27.07.1998  Massachusetts
# 2  eehe1434  08.08.1950          Idaho
# 3  hkxj1334  03.08.1969        Florida
# 4  jjbd1412  26.07.2001        Georgia
# 5000

# %%
users_json = pd.read_json("jcpenney_reviewers.json", lines=True) #importing user data
display(users_json)
print(len(users_json))
# Out:
#       Username         DOB          State  \
# 0     bkpn1412  31.07.1983         Oregon
# 1     gqjs4414  27.07.1998  Massachusetts
# 2     eehe1434  08.08.1950          Idaho
# 3     hkxj1334  03.08.1969        Florida
# 4     jjbd1412  26.07.2001        Georgia
# ...        ...         ...            ...
# 4995  mfnn1212  27.07.1997       Delaware
# 4996  ejnb3414  01.08.1976      Minnesota
# 4997  pdzw1433  28.07.1994           Ohio
# 4998  npha1342  07.08.1953        Montana
# 4999  yuoc2324  02.08.1975   South Dakota
#
#                                                Reviewed
# 0                    [cea76118f6a9110a893de2b7654319c0]
# 1                    [fa04fe6c0dd5189f54fe600838da43d3]
# 2                                                    []
# 3     [f129b1803f447c2b1ce43508fb822810, 3b0c9bc0be6...
# 4                                                    []
# ...                                                 ...
# 4995                 [d6cd506246bd17afa611b6a06236713c]
# ...

# %%
#Finding out how which states are represented in the data

states = users_csv["State"].unique()
display(states)
# Out:
# array(['Oregon', 'Massachusetts', 'Idaho', 'Florida', 'Georgia',
#        'Montana', 'Pennsylvania', 'Connecticut', 'Arkansas', 'Nebraska',
#        'California', 'New Hampshire', 'District of Columbia',
#        'Washington', 'Minnesota', 'New Mexico', 'Virginia', 'Kansas',
#        'Illinois', 'North Dakota', 'Colorado', 'New York',
#        'Minor Outlying Islands', 'Northern Mariana Islands',
#        'West Virginia', 'Texas', 'South Dakota', 'Maryland', 'Maine',
#        'Ohio', 'Rhode Island', 'Michigan', 'Alaska', 'Iowa', 'Oklahoma',
#        'Mississippi', 'South Carolina', 'Missouri', 'New Jersey',
#        'Tennessee', 'North Carolina', 'Guam', 'Wyoming', 'Delaware',
#        'Vermont', 'Indiana', 'Louisiana', 'Wisconsin', 'Hawaii',
#        'Puerto Rico', 'Alabama', 'Kentucky', 'Arizona', 'Nevada', 'Utah',
#        'American Samoa', 'U.S. Virgin Islands'], dtype=object)

# %%
#Finding out how many users there are per state

state_count = users_csv["State"].value_counts()

print(state_count)

# %% [markdown]
# ## Plotting data to show states which have highest and lowest number of users/customers
#
# I did not use this visualisation in the report as there was not enough space in the 5 pages

# %%
states = state_count.index #extracting states for y axis indexes
counts = state_count.values #extracting numerical data for number of users on x axis
y = np.arange(len(states)) #creating y co-ordinates
print(type(counts))
# Out:
# <class 'numpy.ndarray'>

# %%
plt.figure(figsize=(8,12)) #Creating figure

plt.scatter(counts,y,
         color="teal",s=50) #plotting data on scatter plot

plt.hlines(
    y, xmin=0,
    xmax=counts,
    color="gray",
    alpha=0.4) #Adding horizontal lines for readability

plt.yticks(y, states, fontsize=9) #defining values on y axis
plt.gca().invert_yaxis() #Reversing y axis to show most users at top

plt.title("User Number Per US State", fontsize=15,pad=12)
plt.xlabel("Number of Users", fontsize=12)
plt.ylabel("US State", fontsize=12)

plt.tight_layout()

plt.savefig("states.png", dpi=300, bbox_inches='tight') #Saving figure to export to report

plt.show()

# %% [markdown]
# ## Plotting users per state on US map with Plotly
#
# I did not use this in the report as exporting to MS Word removes interactivity of map and it unclear.
#
# If I had more space in the report, I would have displayed this map alongside a table of the states and their user numbers.
#
# I opted for a table in teh report as I think it shows the data more clearly.

# %%
import plotly.graph_objects as go #importing library

# %%
users = pd.read_csv("users.csv") #importing user data

# %%
# Creating a subset which shows users per state

state_counts = users["State"].value_counts().reset_index()
state_counts.columns = ["State", "user_count"]

# %%
user_counts = state_counts["user_count"].sum() #Totalling users per state

display(state_counts.head())
print(user_counts)
# Out:
#                       State  user_count
# 0             Massachusetts         107
# 1                  Delaware         106
# 2                   Vermont         103
# 3  Northern Mariana Islands         102
# 4                New Jersey         101
# 5000

# %%
states = users_csv["State"].unique() #Looking at what states are in the dataset
display(states)
# Out:
# array(['Oregon', 'Massachusetts', 'Idaho', 'Florida', 'Georgia',
#        'Montana', 'Pennsylvania', 'Connecticut', 'Arkansas', 'Nebraska',
#        'California', 'New Hampshire', 'District of Columbia',
#        'Washington', 'Minnesota', 'New Mexico', 'Virginia', 'Kansas',
#        'Illinois', 'North Dakota', 'Colorado', 'New York',
#        'Minor Outlying Islands', 'Northern Mariana Islands',
#        'West Virginia', 'Texas', 'South Dakota', 'Maryland', 'Maine',
#        'Ohio', 'Rhode Island', 'Michigan', 'Alaska', 'Iowa', 'Oklahoma',
#        'Mississippi', 'South Carolina', 'Missouri', 'New Jersey',
#        'Tennessee', 'North Carolina', 'Guam', 'Wyoming', 'Delaware',
#        'Vermont', 'Indiana', 'Louisiana', 'Wisconsin', 'Hawaii',
#        'Puerto Rico', 'Alabama', 'Kentucky', 'Arizona', 'Nevada', 'Utah',
#        'American Samoa', 'U.S. Virgin Islands'], dtype=object)

# %%
# Removing US territories so that the remaining states align with the US map graph

remove = ["Minor Outlying Islands", "Northern Mariana Islands", 
          "Guam", "Puerto Rico", "American Samoa", "U.S. Virgin Islands",
          "District of Columbia"]

to_drop = state_counts["State"].isin(remove) #Removing the above states

# Creating a subset of the filtered states

states_filtered = state_counts[~to_drop]
states_filtered = states_filtered.reset_index(drop=True)

# %%
#display(states_filtered)
print(len(states_filtered))
# Out:
# 50

# %%
# Converting state names to state codes - required for mapping onto go.Choropleth

state_codes = {"Alabama": "AL", "Alaska": "AK", "Arizona": "AZ", "Arkansas": "AR",
    "California": "CA", "Colorado": "CO", "Connecticut": "CT", "Delaware": "DE",
    "Florida": "FL", "Georgia": "GA", "Hawaii": "HI", "Idaho": "ID",
    "Illinois": "IL", "Indiana": "IN", "Iowa": "IA", "Kansas": "KS",
    "Kentucky": "KY", "Louisiana": "LA", "Maine": "ME", "Maryland": "MD",
    "Massachusetts": "MA", "Michigan": "MI", "Minnesota": "MN",
    "Mississippi": "MS", "Missouri": "MO", "Montana": "MT", "Nebraska": "NE",
    "Nevada": "NV", "New Hampshire": "NH", "New Jersey": "NJ", "New Mexico": "NM",
    "New York": "NY", "North Carolina": "NC", "North Dakota": "ND", "Ohio": "OH",
    "Oklahoma": "OK", "Oregon": "OR", "Pennsylvania": "PA", "Rhode Island": "RI",
    "South Carolina": "SC", "South Dakota": "SD", "Tennessee": "TN", "Texas": "TX",
    "Utah": "UT", "Vermont": "VT", "Virginia": "VA", "Washington": "WA",
    "West Virginia": "WV", "Wisconsin": "WI", "Wyoming": "WY",
    "District of Columbia": "DC"}

# %%
# Adding state codes to data frame

states_filtered["state_codes"] = states_filtered["State"].map(state_codes)
#display(states_filtered)

# %%
# Plotting information onto map

fig = go.Figure(data=go.Choropleth(
    locations=states_filtered["state_codes"],
    z = states_filtered["user_count"].astype(int),
    locationmode = "USA-states",
    colorscale="Greens",
    colorbar_title="Number of Users",)) #imported Choropleth map, defined data values for the map, added labels

# Improving map format

fig.update_layout(
    geo=dict(showframe=False, showcoastlines=True, 
             projection_type='albers usa'),
    title_text="Users by US State",
    margin=dict(l=0, r=0, t=50, b=0)) #removing frame around map, showing coastlines, defining US map, defining space around figure

fig.show()

# %%
#Creating dataframes to display alongside the map showing the 10 states with most and least users

top_10 = state_counts.head(10)
bottom_10 = state_counts.tail(10)

print(top_10)
# Out:
#                       State  user_count
# 0             Massachusetts         107
# 1                  Delaware         106
# 2                   Vermont         103
# 3  Northern Mariana Islands         102
# 4                New Jersey         101
# 5                  Oklahoma         100
# 6                California          99
# 7                  Kentucky          99
# 8                   Montana          97
# 9                  Virginia          96

# %% [markdown]
# ## Analysing number of reviews by age group

# %%
reviews = pd.read_csv("reviews.csv") #importing data 
print(reviews.shape)
display(reviews.head(5))
# Out:
# (39063, 4)
#                             Uniq_id  Username  Score  \
# 0  b6c0b6bea69c722939585baeac73c13d  fsdv4141      2
# 1  b6c0b6bea69c722939585baeac73c13d  krpz1113      1
# 2  b6c0b6bea69c722939585baeac73c13d  mbmg3241      2
# 3  b6c0b6bea69c722939585baeac73c13d  zeqg1222      0
# 4  b6c0b6bea69c722939585baeac73c13d  nvfn3212      3
#
#                                               Review
# 0  You never have to worry about the fit...Alfred...
# 1  Good quality fabric. Perfect fit. Washed very ...
# 2  I do not normally wear pants or capris that ha...
# 3  I love these capris! They fit true to size and...
# 4  This product is very comfortable and the fabri...

# %%
users = pd.read_csv("users.csv") #importing data
print(users.shape)
display(users.head(5))
# Out:
# (5000, 3)
#    Username         DOB          State
# 0  bkpn1412  31.07.1983         Oregon
# 1  gqjs4414  27.07.1998  Massachusetts
# 2  eehe1434  08.08.1950          Idaho
# 3  hkxj1334  03.08.1969        Florida
# 4  jjbd1412  26.07.2001        Georgia

# %%
merged = pd.merge(users,reviews, how="inner", on="Username") #Used inner join incase there was data in each set that doesn't match

# %%
print(merged.shape) #checking how many rows are in the dataset
# Out:
# (39080, 6)

# %%
display(merged.head())
# Out:
#    Username         DOB   State                           Uniq_id  Score  \
# 0  bkpn1412  31.07.1983  Oregon  2565bf02ec05a59cd1fd78955dda108d      0
# 1  bkpn1412  31.07.1983  Oregon  e09b42d19cd350f9762f92d59ecf88ba      2
# 2  bkpn1412  31.07.1983  Oregon  cea76118f6a9110a893de2b7654319c0      0
# 3  bkpn1412  31.07.1983  Oregon  bc177e6724df06c676fd526e6d32461d      2
# 4  bkpn1412  31.07.1983  Oregon  a0d0f5f772021d6320048dc7b61fb551      5
#
#                                               Review
# 0  Love this heated mattress pad! Ordered the que...
# 1  I am 511 and a size 6, with a very straight fi...
# 2  I like the jacket accept it is thin not and th...
# 3  Soft, comfortable, and it fits nice. Whats not...
# 4  I bought the quick dri bath rug in the size 21...

# %% [markdown]
# ## Converting DOB's to age bands

# %%
from datetime import datetime #Importing library

# %%
merged["DOB"] = pd.to_datetime(merged["DOB"], format="%d.%m.%Y", errors="coerce") #Ensuring DOB is right format

today = datetime.now()

merged["Age"] = 2025 - merged["DOB"].dt.year #Converting DOB to "age"
merged["Age"] = merged["Age"].astype(int, errors = "ignore") #Making "age" int values

bands = ["20-29", "30-39", "40-49", "50-59", "60-69", "70-79"] #Defining age bands
bins = [20,30,40,50,60,70,80] #Defining bins

merged["Age_band"] = pd.cut(merged["Age"], #Sorting values into bins
                              bins=bins,
                              labels=bands,
                             right=False)

ages_counts = merged.groupby("Age_band").size().reset_index(name = "Reviews") #Creating a subset to plot



display(merged.head())
display(ages_counts.head())
# Out:
# C:\Users\Danie\AppData\Local\Temp\ipykernel_13452\2961809253.py:16: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#    Username        DOB   State                           Uniq_id  Score  \
# 0  bkpn1412 1983-07-31  Oregon  2565bf02ec05a59cd1fd78955dda108d      0
# 1  bkpn1412 1983-07-31  Oregon  e09b42d19cd350f9762f92d59ecf88ba      2
# 2  bkpn1412 1983-07-31  Oregon  cea76118f6a9110a893de2b7654319c0      0
# 3  bkpn1412 1983-07-31  Oregon  bc177e6724df06c676fd526e6d32461d      2
# 4  bkpn1412 1983-07-31  Oregon  a0d0f5f772021d6320048dc7b61fb551      5
#
#                                               Review  Age Age_band
# 0  Love this heated mattress pad! Ordered the que...   42    40-49
# 1  I am 511 and a size 6, with a very straight fi...   42    40-49
# ...

# %% [markdown]
# ## Visualising data

# %%
plt.figure(figsize=(7,7)) #Setting figure size

plt.bar(ages_counts["Age_band"],ages_counts["Reviews"], color="limegreen",edgecolor="black",
       linewidth=0.7) #Plotting bar chart

plt.suptitle("Number of Reviews by Age Group")
plt.xlabel("Age Group", fontsize=12)
plt.ylabel("Number of Reviews", fontsize=12)
plt.ylim(3000,8500) #Changed y axis to better show differences between groups

plt.savefig("ages.png", dpi=300, bbox_inches='tight') #Saving figure to export to report


plt.show()

# %% [markdown]
# ## Considerations and further work

# %% [markdown]
# For this assignment, I decided to only use the data provided and try to do the basics well, not overcomplicating things. I perfomed basic feature engineering, for e.g. creating age and age band columns from DOB. Aditionally, only having 5 pages to report meant there were limits to what I could include. To expand on the work I have done here, I would consider the following to be appropriate:
#
# - Find data on population density in each US state to compare this with the Users by US State data, identifying whether the distribution of users is comparative to the population distirbutions between US states.
# - Plot various variables using Linear Regression to look for correlations, for e.g. I would have used this method to explore the correlation between product price and average user rating to identiy whether more expensive products recieve better reviews.
# - Look at sale price to show how much each product had been reduced
